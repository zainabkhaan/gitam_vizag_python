# %%
filepath='datafiles/Match.csv'

# %%
import pandas as pd
filepath='datafiles/Match (1).csv'
def readcsv(filepath):
    return pd.read_csv(filepath)
df=readcsv(filepath)
print (df)
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
df.groupby('Season_Year').count()
# Out:
#              Match_SK  match_id  Team1  Team2  match_date  Venue_Name  \
# Season_Year
# 2008               58        58     58     58          58          58
# 2009               57        57     57     57          57          57
# 2010               60        60     60     60          60          60
# 2011               73        73     73     73          73          73
# 2012               74        74     74     74          74          74
# 2013               76        76     76     76          76          76
# 2014               60        60     60     60          60          60
# 2015               59        59     59     59          59          59
# 2016               60        60     60     60          60          60
# 2017               60        60     60     60          60          59
#
#              City_Name  Country_Name  Toss_Winner  match_winner  Toss_Name  \
# Season_Year
# 2008                58            58           58            58         58
# ...

# %%
n_df =df[['match_winner','Season_Year']]
n_df[n_df.Season_Year==2011]
t = df['match_winner'].value_counts().index
w = df['match_winner'].value_counts().values
plt.barh(t,w)
plt.show()

# %%
a = df[['ManOfMach','City_Name']]
m=a[a.City_Name=='Hyderabad']
m.groupby('ManOfMach').count()
# Out:
#                    City_Name
# ManOfMach
# A Mishra                   2
# AB Dinda                   1
# AT Rayudu                  1
# B Kumar                    1
# CH Morris                  1
# DA Warner                  6
# DJ Bravo                   1
# DJG Sammy                  1
# DW Steyn                   3
# G Gambhir                  1
# GH Vihari                  2
# I Sharma                   1
# MJ McClenaghan             1
# MR Marsh                   1
# Mandeep Singh              1
# Mustafizur Rahman          1
# PA Patel                   1
# PC Valthaty                1
# R Vinay Kumar              1
# SC Ganguly                 1
# SE Marsh                   1
# SK Raina                   2
# SK Trivedi                 1
# SL Malinga                 1
# UT Yadav                   1
# V Kohli                    1
# V Sehwag                   2
# WP Saha                    1
# YK Pathan                  2
